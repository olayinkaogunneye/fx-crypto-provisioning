# %%
import sys
import os

# 1. Use 'default' instead of the specific Lakehouse name
script_path = '/lakehouse/default/Files/ingestion'

# 2. Add to sys.path if not already there
if script_path not in sys.path:
    sys.path.append(script_path)

# 3. Double-check for typos: ensure the file is named 'fx_sftp_ingesst.py' 
# (Note: your error shows 'ingesst' with two 's's—check if the file matches!)
import fx_sftp_ingesst

fx_sftp_ingesst.run_fx_ingestion()
# Out:
# StatementMeta(, 3956be9d-3dda-4be5-b1a9-2ade74d0edc6, 5, Finished, Available, Finished, False)
# Starting FX ingestion process...
# ...
# ✔ Download complete. Rows loaded: 272240
# ✔ Metadata added to DataFrame.
# ✔ Data successfully written to Bronze table: bronze_fx_rates_raw
# ✔ FX ingestion process completed successfully.

# %%
import sys
import os

# 1. Use 'default' instead of the specific Lakehouse name
script_path = '/lakehouse/default/Files/ingestion'

# 2. Add to sys.path if not already there
if script_path not in sys.path:
    sys.path.append(script_path)

# 3. Double-check for typos: ensure the file is named 'fx_sftp_ingesst.py' 
# (Note: your error shows 'ingesst' with two 's's—check if the file matches!)
import crypto_api_ingest

crypto_api_ingest.run_crypto_ingestion()
# Out:
# StatementMeta(, 654f48f3-7d1c-4f9c-9d7b-7d5b12d0271f, 3, Finished, Available, Finished, False)
# Starting Crypto ingestion process...
# Calling CoinGecko API: https://api.coingecko.com/api/v3/simple/price?ids=bitcoin,ethereum,solana,cardano,xrp,dogecoin,polkadot&vs_currencies=usd
# ✓ API call successful.
# ✓ Parsed 6 crypto price records.
# ✓ Crypto data successfully written to Bronze table: bronze_crypto_prices_raw
# ✓ Crypto ingestion process completed successfully.
